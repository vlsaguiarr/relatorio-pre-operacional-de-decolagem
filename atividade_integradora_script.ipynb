# %%
import pandas as pd
import numpy as np

# Definir o número de linhas
n_rows = 500

# Gerar dados fictícios
data = {
    'temperatura_interna_celsius': np.random.uniform(20.0, 25.0, n_rows),
    'temperatura_externa_celsius': np.random.uniform(-150.0, 120.0, n_rows),
    'integridade_estrutural': np.random.choice([0, 1], n_rows, p=[0.3, 0.7]),
    'niveis_energia_percentual': np.random.uniform(0.0, 100.0, n_rows),
    'pressao_tanques_psi': np.random.uniform(50.0, 185.0, n_rows),
    'status_modulos_criticos': np.random.choice(['Normal', 'Atenção', 'Crítico'], n_rows, p=[0.7, 0.25, 0.05])

}


# Criar o DataFrame
df_ficticio = pd.DataFrame(data)

df_ficticio.to_csv('dados_ficticios.csv', index=False)

# %%
import pandas as pd
import numpy as np

n_rows = 500


data_energia = {
    'Capacidade total (kwh)': np.random.uniform(2000, 10000, n_rows),
    'Carga atual (%)': np.random.uniform(60.0, 100.0, n_rows),
    'Consumo estimado na decolagem (kwh)': np.random.uniform(500, 2000, n_rows),
    'Perdas energéticas (kwh)': np.random.uniform(50, 300, n_rows)
}

df_analise_energia = pd.DataFrame(data_energia)

df_analise_energia.to_csv('analise_energia.csv', index=False)

# %%
from os import abort
dados=pd.read_csv('dados_ficticios.csv')

def decisão(row):
  cond_integridade = (row["integridade_estrutural"] == 1)
  cond_energia = (row["niveis_energia_percentual"] >= 70.0)
  cond_pressao = (row["pressao_tanques_psi"] >= 50.0) and (row["pressao_tanques_psi"] <= 180.0)
  cond_modulo_status = (row["status_modulos_criticos"] == str("Normal"))
  cond_temperatura_interna = (row["temperatura_interna_celsius"] >= 20.0) and (row["temperatura_interna_celsius"] <= 25.0)
  cond_temperatura_externa = (row["temperatura_externa_celsius"] >= -152.0) and (row["temperatura_externa_celsius"] <= 125.0)

  failed_conditions = []
  if not cond_integridade:
    failed_conditions.append('Integridade Estrutural')
  if not cond_energia:
    failed_conditions.append('Níveis de Energia')
  if not cond_pressao:
    failed_conditions.append('Pressão dos Tanques')
  if not cond_modulo_status:
    failed_conditions.append('Status dos Módulos Críticos')
  if not cond_temperatura_interna:
    failed_conditions.append('Temperatura Interna')
  if not cond_temperatura_externa:
    failed_conditions.append('Temperatura Externa')

  if not failed_conditions:
    return 'PRONTO PARA DECOLAR', ''
  else:
    return 'DECOLAGEM ABORTADA', ', '.join(failed_conditions)

dados[['decisao', 'condicao_falha']] = dados.apply(lambda row: pd.Series(decisão(row)), axis=1)

ready = dados[dados['decisao'] == 'PRONTO PARA DECOLAR'].shape[0]

abort = dados[dados['decisao'] == 'DECOLAGEM ABORTADA'].shape[0]

print(f"Quantidade de decisões 'PRONTO PARA DECOLAR': {ready}")
print(f"Quantidade de decisões 'DECOLAGEM ABORTADA': {abort}")

print(f"Porcentagem de decisões 'PRONTO PARA DECOLAR': {ready / dados.shape[0] * 100:.2f}%")
print(f"Porcentagem de decisões 'DECOLAGEM ABORTADA': {abort / dados.shape[0] * 100:.2f}%")

print(f"pProporção (1 para x) 'PRONTO PARA DECOLAR': {dados.shape[0] / ready:.2f}")
print(f"Proporção (1 para x) 'DECOLAGEM ABORTADA': {dados.shape[0] / abort:.2f}")

display(dados.head(16))
# Out:
# Quantidade de decisões 'PRONTO PARA DECOLAR': 68
# Quantidade de decisões 'DECOLAGEM ABORTADA': 432
# Porcentagem de decisões 'PRONTO PARA DECOLAR': 13.60%
# Porcentagem de decisões 'DECOLAGEM ABORTADA': 86.40%
# pProporção (1 para x) 'PRONTO PARA DECOLAR': 7.35
# Proporção (1 para x) 'DECOLAGEM ABORTADA': 1.16
#     temperatura_interna_celsius  temperatura_externa_celsius  \
# 0                     23.330945                  -143.600669
# 1                     21.560129                    19.598358
# 2                     22.848779                    75.983140
# 3                     21.251945                   -23.568206
# 4                     21.992812                   -81.679615
# 5                     21.026556                   -50.387292
# 6                     22.340246                   -90.053529
# 7                     20.002069                  -110.796554
# 8                     22.165426                   -31.013456
# 9                     23.544226                   103.055325
# 10                    23.654113                   -93.482951
# 11                    21.484467                    35.639984
# 12                    22.040050                   -80.504696
# 13                    22.846084                    80.355662
# 14                    22.076367                   102.334135
# 15                    22.076992                   -98.829024
#
#     integridade_estrutural  niveis_energia_percentual  pressao_tanques_psi  \
# 0                        1                  64.297575           138.503516
# 1                        1                  71.982991           117.550600
# 2                        1                  56.171440            65.690637
# 3                        1                   7.734865           141.579405
# 4                        1                  13.036174           148.628434
# 5                        1                  10.317130           151.950594
# 6                        1                  37.699577           129.741920
# 7                        1                  84.234261           134.118256
# 8                        1                  33.428581           125.059426
# 9                        1                   1.715363           136.752478
# 10                       0                  49.140318            95.465022
# 11                       0                  76.343172            96.973583
# 12                       1                  44.599589           143.137844
# 13                       1                  21.095256           165.161883
# 14                       1                  53.191560           178.849086
# 15                       1                  52.103230           179.182783
#
#    status_modulos_criticos              decisao  \
# 0                   Normal   DECOLAGEM ABORTADA
# 1                  Atenção   DECOLAGEM ABORTADA
# 2                   Normal   DECOLAGEM ABORTADA
# 3                  Crítico   DECOLAGEM ABORTADA
# 4                   Normal   DECOLAGEM ABORTADA
# 5                  Atenção   DECOLAGEM ABORTADA
# 6                   Normal   DECOLAGEM ABORTADA
# 7                   Normal  PRONTO PARA DECOLAR
# 8                   Normal   DECOLAGEM ABORTADA
# 9                   Normal   DECOLAGEM ABORTADA
# 10                  Normal   DECOLAGEM ABORTADA
# 11                  Normal   DECOLAGEM ABORTADA
# 12                 Atenção   DECOLAGEM ABORTADA
# 13                 Crítico   DECOLAGEM ABORTADA
# 14                 Crítico   DECOLAGEM ABORTADA
# 15                  Normal   DECOLAGEM ABORTADA
#
#                                     condicao_falha
# 0                                Níveis de Energia
# 1                      Status dos Módulos Críticos
# 2                                Níveis de Energia
# 3   Níveis de Energia, Status dos Módulos Críticos
# 4                                Níveis de Energia
# 5   Níveis de Energia, Status dos Módulos Críticos
# 6                                Níveis de Energia
# 7
# 8                                Níveis de Energia
# 9                                Níveis de Energia
# 10       Integridade Estrutural, Níveis de Energia
# 11                          Integridade Estrutural
# 12  Níveis de Energia, Status dos Módulos Críticos
# 13  Níveis de Energia, Status dos Módulos Críticos
# 14  Níveis de Energia, Status dos Módulos Críticos
# 15                               Níveis de Energia

# %%
import pandas as pd

autonomiaI = pd.read_csv('analise_energia.csv')

autonomiaI['Carga atual (kwh)'] = autonomiaI['Capacidade total (kwh)'] *  (autonomiaI['Carga atual (%)'] / 100)

autonomiaI['Autonomia inicial (kwh)'] = autonomiaI['Carga atual (kwh)'] - autonomiaI['Consumo estimado na decolagem (kwh)'] - autonomiaI['Perdas energéticas (kwh)']

display(autonomiaI.head(16))
# Out:
#     Capacidade total (kwh)  Carga atual (%)  \
# 0              3429.216201        62.081340
# 1              7849.211734        86.501723
# 2              7047.443444        80.367017
# 3              6431.206729        85.832116
# 4              5793.229182        90.977739
# 5              6345.913152        80.385689
# 6              4799.036099        88.793659
# 7              6192.679677        94.633635
# 8              9032.112552        69.248304
# 9              9643.985845        80.073880
# 10             3159.412033        67.976664
# 11             8246.920118        71.647367
# 12             8210.669347        93.634520
# 13             9834.823126        78.687094
# 14             5927.276846        69.230631
# 15             4847.131747        85.778710
#
#     Consumo estimado na decolagem (kwh)  Perdas energéticas (kwh)  \
# 0                           1009.422578                 54.415615
# 1                            653.320500                128.174195
# 2                            974.756036                179.278329
# 3                           1767.718305                182.616302
# 4                           1896.549122                204.369971
# 5                           1548.676494                248.059501
# 6                           1145.938166                 87.938593
# 7                           1808.261080                175.395679
# 8                           1166.023095                258.354086
# 9                            802.610235                 95.827155
# 10                           765.852942                 77.591593
# 11                           874.432267                223.658580
# 12                           704.588254                134.404316
# 13                           997.138576                 52.647312
# 14                           553.110991                103.189719
# 15                           565.181449                219.148744
#
#     Carga atual (kwh)  Autonomia inicial (kwh)
# 0         2128.903352              1065.065160
# 1         6789.703356              6008.208661
# 2         5663.820064              4509.785699
# 3         5520.040818              3569.706211
# 4         5270.548914              3169.629821
# 5         5101.206036              3304.470041
# 6         4261.239739              3027.362980
# 7         5860.357890              3876.701131
# 8         6254.584760              4830.207579
# 9         7722.313652              6823.876263
# 10        2147.662910              1304.218375
# 11        5908.701123              4810.610276
# 12        7688.020864              6849.028294
# 13        7738.736488              6688.950600
# 14        4103.491177              3447.190467
# 15        4157.807106              3373.476913

# %%
print('--- Visão Geral do Dataset (df.info()) ---')
df_ficticio.info()

print('\n--- Descrição Estatística do Dataset (df.describe()) ---\n')
df_ficticio.describe()
# Out:
# --- Visão Geral do Dataset (df.info()) ---
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   temperatura_interna_celsius  500 non-null    float64
#  1   temperatura_externa_celsius  500 non-null    float64
#  2   integridade_estrutural       500 non-null    int64
#  3   niveis_energia_percentual    500 non-null    float64
#  4   pressao_tanques_psi          500 non-null    float64
#  5   status_modulos_criticos      500 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 23.6 KB
#
# --- Descrição Estatística do Dataset (df.describe()) ---
#        temperatura_interna_celsius  temperatura_externa_celsius  \
# count                   500.000000                   500.000000
# mean                     22.476197                   -15.527875
# std                       1.477875                    73.885258
# min                      20.002069                  -149.679720
# 25%                      21.120429                   -73.832975
# 50%                      22.393107                   -13.485032
# 75%                      23.785584                    44.787425
# max                      24.985219                   118.985421
#
#        integridade_estrutural  niveis_energia_percentual  pressao_tanques_psi
# count              500.000000                 500.000000           500.000000
# mean                 0.696000                  50.869056           115.082182
# std                  0.460443                  28.716991            38.491495
# min                  0.000000                   0.015980            50.267727
# 25%                  0.000000                  27.256220            80.392795
# 50%                  1.000000                  49.981499           115.205643
# 75%                  1.000000                  76.443367           146.663338
# max                  1.000000                  99.790819           184.504445

# %%
print('--- Visão Geral do Dataset de Análise Energética (autonomiaI.info()) ---')
autonomiaI.info()

print('\n--- Descrição Estatística do Dataset de Análise Energética (autonomiaI.describe()) ---\n')
autonomiaI.describe()
# Out:
# --- Visão Geral do Dataset de Análise Energética (autonomiaI.info()) ---
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Capacidade total (kwh)               500 non-null    float64
#  1   Carga atual (%)                      500 non-null    float64
#  2   Consumo estimado na decolagem (kwh)  500 non-null    float64
#  3   Perdas energéticas (kwh)             500 non-null    float64
#  4   Carga atual (kwh)                    500 non-null    float64
#  5   Autonomia inicial (kwh)              500 non-null    float64
# dtypes: float64(6)
# memory usage: 23.6 KB
#
# --- Descrição Estatística do Dataset de Análise Energética (autonomiaI.describe()) ---
#        Capacidade total (kwh)  Carga atual (%)  \
# count              500.000000       500.000000
# mean              6124.306851        79.482993
# std               2410.496232        11.810516
# min               2023.609267        60.114811
# 25%               3929.605561        68.902488
# 50%               6204.516144        79.390658
# 75%               8298.519872        89.970766
# max               9983.206542        99.768338
#
#        Consumo estimado na decolagem (kwh)  Perdas energéticas (kwh)  \
# count                           500.000000                500.000000
# mean                           1256.562079                168.490284
# std                             431.993978                 72.876007
# min                             505.108462                 50.714357
# 25%                             900.309661                101.464308
# 50%                            1245.954270                164.424595
# 75%                            1612.636570                228.014436
# max                            1997.895685                299.875868
#
#        Carga atual (kwh)  Autonomia inicial (kwh)
# count         500.000000               500.000000
# mean         4868.920341              3443.867979
# std          2064.820887              2093.461674
# min          1284.199390              -734.484191
# 25%          3073.485039              1751.652838
# 50%          4906.247198              3394.250668
# 75%          6496.662960              5059.538559
# max          9706.152591              8687.947757

# %%
# @title
import pandas as pd
from IPython.display import display, Markdown, HTML
from collections import Counter

# --- Análise Geral da Decisão de Lançamento ---
display(Markdown("## Análise da Decisão de Lançamento"))
display(HTML(f"""
<div style="border: 1px solid #ccc; padding: 15px; border-radius: 5px; background-color: #f9f9f9;">
    <p><b>Total de Registros Avaliados:</b> {dados.shape[0]}</p>
    <p><b>Decisões 'PRONTO PARA DECOLAR':</b> {ready} ({ready / dados.shape[0] * 100:.2f}%)</p>
    <p><b>Decisões 'DECOLAGEM ABORTADA':</b> {abort} ({abort / dados.shape[0] * 100:.2f}%)</p>
    <p><b>Proporção 'PRONTO PARA DECOLAR':</b> 1 em cada {dados.shape[0] / ready:.2f} registros</p>
    <p><b>Proporção 'DECOLAGEM ABORTADA':</b> 1 em cada {dados.shape[0] / abort:.2f} registros</p>
</div>
"""))

# --- Detalhamento de Anomalias e Riscos para Decolagens Abortadas ---
display(Markdown("## Detalhamento de Anomalias e Riscos (Decolagens Abortadas)"))

aborted_data = dados[dados['decisao'] == 'DECOLAGEM ABORTADA']

if not aborted_data.empty:
    all_failed_conditions = []
    for conditions_str in aborted_data['condicao_falha']:
        if conditions_str: # Ignora strings vazias
            all_failed_conditions.extend([cond.strip() for cond in conditions_str.split(',')])

    if all_failed_conditions:
        condition_counts = Counter(all_failed_conditions)
        sorted_conditions = condition_counts.most_common()

        display(Markdown("### Frequência das Condições de Falha:"))
        counts_str = "<ul style=\"list-style-type: disc; margin-left: 20px;\">"
        for condition, count in sorted_conditions:
            counts_str += f"<li><b>{condition}</b>: {count} ocorrências</li>"
        counts_str += "</ul>"
        display(HTML(counts_str))

        display(Markdown("### Sugestões de Risco e Próximos Passos:"))
        risks_suggestions = []

        if 'Integridade Estrutural' in condition_counts:
            risks_suggestions.append(
                "<b>Integridade Estrutural:</b> A alta frequência de falhas na integridade estrutural indica a necessidade de revisões rigorosas nos processos de fabricação, inspeção e manutenção dos componentes estruturais da nave. Isso pode envolver o uso de materiais mais resistentes, design aprimorado ou tecnologias de detecção de falhas mais avançadas."
            )
        if 'Níveis de Energia' in condition_counts:
            risks_suggestions.append(
                "<b>Níveis de Energia:</b> Falhas nos níveis de energia sugerem que o sistema de gerenciamento de energia ou as fontes de energia (baterias, células de combustível) podem não estar adequados. É crucial otimizar a capacidade de armazenamento, monitoramento do consumo e garantir que as reservas de energia atendam aos requisitos mínimos para todas as fases da missão."
            )
        if 'Pressão dos Tanques' in condition_counts:
            risks_suggestions.append(
                "<b>Pressão dos Tanques:</b> Anomalias na pressão dos tanques indicam problemas potenciais com válvulas, selos, sensores ou até mesmo a composição dos propelentes. A falha nesse parâmetro é crítica e pode levar a eventos catastróficos. Uma revisão detalhada dos sistemas de propulsão e pressurização é fundamental."
            )
        if 'Status dos Módulos Críticos' in condition_counts:
            risks_suggestions.append(
                "<b>Status dos Módulos Críticos:</b> Se módulos críticos não estão em status 'Normal', isso aponta para falhas em subsistemas essenciais (navegação, comunicação, controle de ambiente, etc.). É vital implementar um diagnóstico mais profundo para identificar a raiz dos problemas nesses módulos e garantir sua redundância ou robustez."
            )
        if 'Temperatura Interna' in condition_counts:
            risks_suggestions.append(
                "<b>Temperatura Interna:</b> Temperaturas internas fora da faixa ideal podem indicar falhas nos sistemas de controle térmico, superaquecimento de componentes eletrônicos ou problemas de isolamento. Manter a temperatura dentro dos limites operacionais é crucial para o desempenho e a vida útil dos equipamentos a bordo."
            )
        if 'Temperatura Externa' in condition_counts:
            risks_suggestions.append(
                "<b>Temperatura Externa:</b> Variações extremas na temperatura externa, se não gerenciadas, podem causar estresse térmico em materiais e componentes. A adequação dos materiais e dos sistemas de isolamento para suportar o ambiente externo é uma área chave para investigação e aprimoramento."
            )

        if risks_suggestions:
            suggestions_str = "<ul style=\"list-style-type: circle; margin-left: 20px;\">"
            for suggestion in risks_suggestions:
                suggestions_str += f"<li>{suggestion}</li>"
            suggestions_str += "</ul>"
            display(HTML(suggestions_str))
        else:
            display(Markdown("Não foram encontradas condições de falha específicas para gerar sugestões detalhadas."))

    else:
        display(Markdown("Não foram encontradas falhas específicas para as decolagens abortadas que contenham condições detalhadas."))
elif abort > 0:
    display(Markdown("Houve decolagens abortadas, mas o campo 'condicao_falha' está vazio ou não detalhado."))
else:
    display(Markdown("Não houve decolagens abortadas neste conjunto de dados."))

# --- Amostra dos Dados com Decisão de Lançamento ---
display(Markdown("## Amostra dos Dados com Decisão de Lançamento"))
display(dados.head().style.set_table_styles([{'selector': '', 'props': [('border', '1px solid #eee')]}, {'selector': 'th', 'props': [('background-color', '#007bff'), ('color', 'white')]}]))
# Out:
# ## Análise da Decisão de Lançamento
# <div style="border: 1px solid #ccc; padding: 15px; border-radius: 5px; background-color: #f9f9f9;">
#     <p><b>Total de Registros Avaliados:</b> 500</p>
#     <p><b>Decisões 'PRONTO PARA DECOLAR':</b> 68 (13.60%)</p>
#     <p><b>Decisões 'DECOLAGEM ABORTADA':</b> 432 (86.40%)</p>
#     <p><b>Proporção 'PRONTO PARA DECOLAR':</b> 1 em cada 7.35 registros</p>
#     <p><b>Proporção 'DECOLAGEM ABORTADA':</b> 1 em cada 1.16 registros</p>
# </div>
# ## Detalhamento de Anomalias e Riscos (Decolagens Abortadas)
# ### Frequência das Condições de Falha:
# <ul style="list-style-type: disc; margin-left: 20px;"><li><b>Níveis de Energia</b>: 342 ocorrências</li><li><b>Integridade Estrutural</b>: 152 ocorrências</li><li><b>Status dos Módulos Críticos</b>: 147 ocorrências</li><li><b>Pressão dos Tanques</b>: 15 ocorrências</li></ul>
# ### Sugestões de Risco e Próximos Passos:
# <ul style="list-style-type: circle; margin-left: 20px;"><li><b>Integridade Estrutural:</b> A alta frequência de falhas na integridade estrutural indica a necessidade de revisões rigorosas nos processos de fabricação, inspeção e manutenção dos componentes estruturais da nave. Isso pode envolver o uso de materiais mais resistentes, design aprimorado ou tecnologias de detecção de falhas mais avançadas.</li><li><b>Níveis de Energia:</b> Falhas nos níveis de energia sugerem que o sistema de gerenciamento de energia ou as fontes de energia (baterias, células de combustível) podem não estar adequados. É crucial otimizar a capacidade de armazenamento, monitoramento do consumo e garantir que as reservas de energia atendam aos requisitos mínimos para todas as fases da missão.</li><li><b>Pressão dos Tanques:</b> Anomalias na pressão dos tanques indicam problemas potenciais com válvulas, selos, sensores ou até mesmo a composição dos propelentes. A falha nesse parâmetro é crítica e pode levar a eventos catastróficos. Uma revisão detalhada dos sistemas de propulsão e pressurização é fundamental.</li><li><b>Status dos Módulos Críticos:</b> Se módulos críticos não estão em status 'Normal', isso aponta para falhas em subsistemas essenciais (navegação, comunicação, controle de ambiente, etc.). É vital implementar um diagnóstico mais profundo para identificar a raiz dos problemas nesses módulos e garantir sua redundância ou robustez.</li></ul>
# ## Amostra dos Dados com Decisão de Lançamento
# <style type="text/css">
# #T_e1599  {
#   border: 1px solid #eee;
# }
# #T_e1599 th {
#   background-color: #007bff;
#   color: white;
# }
# </style>
# <table id="T_e1599">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1599_level0_col0" class="col_heading level0 col0" >temperatura_interna_celsius</th>
#       <th id="T_e1599_level0_col1" class="col_heading level0 col1" >temperatura_externa_celsius</th>
#       <th id="T_e1599_level0_col2" class="col_heading level0 col2" >integridade_estrutural</th>
#       <th id="T_e1599_level0_col3" class="col_heading level0 col3" >niveis_energia_percentual</th>
#       <th id="T_e1599_level0_col4" class="col_heading level0 col4" >pressao_tanques_psi</th>
#       <th id="T_e1599_level0_col5" class="col_heading level0 col5" >status_modulos_criticos</th>
#       <th id="T_e1599_level0_col6" class="col_heading level0 col6" >decisao</th>
#       <th id="T_e1599_level0_col7" class="col_heading level0 col7" >condicao_falha</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1599_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1599_row0_col0" class="data row0 col0" >23.330945</td>
#       <td id="T_e1599_row0_col1" class="data row0 col1" >-143.600669</td>
#       <td id="T_e1599_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_e1599_row0_col3" class="data row0 col3" >64.297575</td>
#       <td id="T_e1599_row0_col4" class="data row0 col4" >138.503516</td>
#       <td id="T_e1599_row0_col5" class="data row0 col5" >Normal</td>
#       <td id="T_e1599_row0_col6" class="data row0 col6" >DECOLAGEM ABORTADA</td>
#       <td id="T_e1599_row0_col7" class="data row0 col7" >Níveis de Energia</td>
#     </tr>
#     <tr>
#       <th id="T_e1599_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1599_row1_col0" class="data row1 col0" >21.560129</td>
#       <td id="T_e1599_row1_col1" class="data row1 col1" >19.598358</td>
#       <td id="T_e1599_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_e1599_row1_col3" class="data row1 col3" >71.982991</td>
#       <td id="T_e1599_row1_col4" class="data row1 col4" >117.550600</td>
#       <td id="T_e1599_row1_col5" class="data row1 col5" >Atenção</td>
#       <td id="T_e1599_row1_col6" class="data row1 col6" >DECOLAGEM ABORTADA</td>
#       <td id="T_e1599_row1_col7" class="data row1 col7" >Status dos Módulos Críticos</td>
#     </tr>
#     <tr>
#       <th id="T_e1599_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1599_row2_col0" class="data row2 col0" >22.848779</td>
#       <td id="T_e1599_row2_col1" class="data row2 col1" >75.983140</td>
#       <td id="T_e1599_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_e1599_row2_col3" class="data row2 col3" >56.171440</td>
#       <td id="T_e1599_row2_col4" class="data row2 col4" >65.690637</td>
#       <td id="T_e1599_row2_col5" class="data row2 col5" >Normal</td>
#       <td id="T_e1599_row2_col6" class="data row2 col6" >DECOLAGEM ABORTADA</td>
#       <td id="T_e1599_row2_col7" class="data row2 col7" >Níveis de Energia</td>
#     </tr>
#     <tr>
#       <th id="T_e1599_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1599_row3_col0" class="data row3 col0" >21.251945</td>
#       <td id="T_e1599_row3_col1" class="data row3 col1" >-23.568206</td>
#       <td id="T_e1599_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_e1599_row3_col3" class="data row3 col3" >7.734865</td>
#       <td id="T_e1599_row3_col4" class="data row3 col4" >141.579405</td>
#       <td id="T_e1599_row3_col5" class="data row3 col5" >Crítico</td>
#       <td id="T_e1599_row3_col6" class="data row3 col6" >DECOLAGEM ABORTADA</td>
#       <td id="T_e1599_row3_col7" class="data row3 col7" >Níveis de Energia, Status dos Módulos Críticos</td>
#     </tr>
#     <tr>
#       <th id="T_e1599_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1599_row4_col0" class="data row4 col0" >21.992812</td>
#       <td id="T_e1599_row4_col1" class="data row4 col1" >-81.679615</td>
#       <td id="T_e1599_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_e1599_row4_col3" class="data row4 col3" >13.036174</td>
#       <td id="T_e1599_row4_col4" class="data row4 col4" >148.628434</td>
#       <td id="T_e1599_row4_col5" class="data row4 col5" >Normal</td>
#       <td id="T_e1599_row4_col6" class="data row4 col6" >DECOLAGEM ABORTADA</td>
#       <td id="T_e1599_row4_col7" class="data row4 col7" >Níveis de Energia</td>
#     </tr>
#   </tbody>
# </table>

# %%
# @title
import pandas as pd
from IPython.display import display, Markdown, HTML
from collections import Counter

# Carregar o DataFrame autonomiaI se não estiver carregado (para execução independente)
if 'autonomiaI' not in locals():
    autonomiaI = pd.read_csv('analise_energia.csv')
    autonomiaI['Carga atual (kwh)'] = autonomiaI['Capacidade total (kwh)'] *  (autonomiaI['Carga atual (%)'] / 100)
    autonomiaI['Autonomia inicial (kwh)'] = autonomiaI['Carga atual (kwh)'] - autonomiaI['Consumo estimado na decolagem (kwh)'] - autonomiaI['Perdas energéticas (kwh)']

# --- Função de Decisão para Análise Energética ---
def decisao_energia(row):
    if row['Autonomia inicial (kwh)'] > 0:
        return 'PRONTO PARA DECOLAR', ''
    else:
        return 'DECOLAGEM ABORTADA', 'Autonomia Energética Insuficiente'

# Aplicar a decisão ao DataFrame de energia
autonomiaI[['decisao', 'condicao_falha']] = autonomiaI.apply(lambda row: pd.Series(decisao_energia(row)), axis=1)

# Contar os resultados
ready_energy = autonomiaI[autonomiaI['decisao'] == 'PRONTO PARA DECOLAR'].shape[0]
abort_energy = autonomiaI[autonomiaI['decisao'] == 'DECOLAGEM ABORTADA'].shape[0]
total_records_energy = autonomiaI.shape[0]

# --- Análise Geral da Decisão de Lançamento (Energia) ---
display(Markdown("## Análise da Decisão de Lançamento (Dados de Energia)"))
display(HTML(f"""
<div style="border: 1px solid #ccc; padding: 15px; border-radius: 5px; background-color: #f9f9f9;">
    <p><b>Total de Registros Avaliados:</b> {total_records_energy}</p>
    <p><b>Decisões 'PRONTO PARA DECOLAR':</b> {ready_energy} ({ready_energy / total_records_energy * 100:.2f}%)</p>
    <p><b>Decisões 'DECOLAGEM ABORTADA':</b> {abort_energy} ({abort_energy / total_records_energy * 100:.2f}%)</p>
    <p><b>Proporção 'PRONTO PARA DECOLAR':</b> 1 em cada {total_records_energy / ready_energy:.2f} registros</p>
    <p><b>Proporção 'DECOLAGEM ABORTADA':</b> 1 em cada {total_records_energy / abort_energy:.2f} registros</p>
</div>
"""))

# --- Detalhamento de Anomalias e Riscos para Decolagens Abortadas (Energia) ---
display(Markdown("## Detalhamento de Anomalias e Riscos (Decolagens Abortadas de Energia)"))

aborted_data_energy = autonomiaI[autonomiaI['decisao'] == 'DECOLAGEM ABORTADA']

if not aborted_data_energy.empty:
    all_failed_conditions_energy = []
    for conditions_str in aborted_data_energy['condicao_falha']:
        if conditions_str: # Ignora strings vazias
            all_failed_conditions_energy.extend([cond.strip() for cond in conditions_str.split(',')])

    if all_failed_conditions_energy:
        condition_counts_energy = Counter(all_failed_conditions_energy)
        sorted_conditions_energy = condition_counts_energy.most_common()

        display(Markdown("### Frequência das Condições de Falha (Energia):"))
        counts_str_energy = "<ul style=\"list-style-type: disc; margin-left: 20px;\">"
        for condition, count in sorted_conditions_energy:
            counts_str_energy += f"<li><b>{condition}</b>: {count} ocorrências</li>"
        counts_str_energy += "</ul>"
        display(HTML(counts_str_energy))

        display(Markdown("### Sugestões de Risco e Próximos Passos (Energia):"))
        risks_suggestions_energy = []

        if 'Autonomia Energética Insuficiente' in condition_counts_energy:
            risks_suggestions_energy.append(
                "<b>Autonomia Energética Insuficiente:</b> A alta frequência de falhas por autonomia energética insuficiente indica que a carga inicial da nave ou a capacidade de seus sistemas de energia não são adequadas para a missão, considerando o consumo e as perdas. É crucial revisar a otimização do uso de energia, aumentar a capacidade de armazenamento ou ajustar os requisitos de carga e consumo para garantir margens de segurança adequadas."
            )

        if risks_suggestions_energy:
            suggestions_str_energy = "<ul style=\"list-style-type: circle; margin-left: 20px;\">"
            for suggestion in risks_suggestions_energy:
                suggestions_str_energy += f"<li>{suggestion}</li>"
            suggestions_str_energy += "</ul>"
            display(HTML(suggestions_str_energy))
        else:
            display(Markdown("Não foram encontradas condições de falha específicas de energia para gerar sugestões detalhadas."))

    else:
        display(Markdown("Não foram encontradas falhas específicas para as decolagens abortadas de energia que contenham condições detalhadas."))
elif abort_energy > 0:
    display(Markdown("Houve decolagens abortadas de energia, mas o campo 'condicao_falha' está vazio ou não detalhado."))
else:
    display(Markdown("Não houve decolagens abortadas neste conjunto de dados de energia."))

# --- Amostra dos Dados de Energia com Decisão de Lançamento ---
display(Markdown("## Amostra dos Dados de Energia com Decisão de Lançamento"))
display(autonomiaI.head().style.set_table_styles([{'selector': '', 'props': [('border', '1px solid #eee')]}, {'selector': 'th', 'props': [('background-color', '#007bff'), ('color', 'white')]}]))
# Out:
# ## Análise da Decisão de Lançamento (Dados de Energia)
# <div style="border: 1px solid #ccc; padding: 15px; border-radius: 5px; background-color: #f9f9f9;">
#     <p><b>Total de Registros Avaliados:</b> 500</p>
#     <p><b>Decisões 'PRONTO PARA DECOLAR':</b> 488 (97.60%)</p>
#     <p><b>Decisões 'DECOLAGEM ABORTADA':</b> 12 (2.40%)</p>
#     <p><b>Proporção 'PRONTO PARA DECOLAR':</b> 1 em cada 1.02 registros</p>
#     <p><b>Proporção 'DECOLAGEM ABORTADA':</b> 1 em cada 41.67 registros</p>
# </div>
# ## Detalhamento de Anomalias e Riscos (Decolagens Abortadas de Energia)
# ### Frequência das Condições de Falha (Energia):
# <ul style="list-style-type: disc; margin-left: 20px;"><li><b>Autonomia Energética Insuficiente</b>: 12 ocorrências</li></ul>
# ### Sugestões de Risco e Próximos Passos (Energia):
# <ul style="list-style-type: circle; margin-left: 20px;"><li><b>Autonomia Energética Insuficiente:</b> A alta frequência de falhas por autonomia energética insuficiente indica que a carga inicial da nave ou a capacidade de seus sistemas de energia não são adequadas para a missão, considerando o consumo e as perdas. É crucial revisar a otimização do uso de energia, aumentar a capacidade de armazenamento ou ajustar os requisitos de carga e consumo para garantir margens de segurança adequadas.</li></ul>
# ## Amostra dos Dados de Energia com Decisão de Lançamento
# <style type="text/css">
# #T_cf5cd  {
#   border: 1px solid #eee;
# }
# #T_cf5cd th {
#   background-color: #007bff;
#   color: white;
# }
# </style>
# <table id="T_cf5cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf5cd_level0_col0" class="col_heading level0 col0" >Capacidade total (kwh)</th>
#       <th id="T_cf5cd_level0_col1" class="col_heading level0 col1" >Carga atual (%)</th>
#       <th id="T_cf5cd_level0_col2" class="col_heading level0 col2" >Consumo estimado na decolagem (kwh)</th>
#       <th id="T_cf5cd_level0_col3" class="col_heading level0 col3" >Perdas energéticas (kwh)</th>
#       <th id="T_cf5cd_level0_col4" class="col_heading level0 col4" >Carga atual (kwh)</th>
#       <th id="T_cf5cd_level0_col5" class="col_heading level0 col5" >Autonomia inicial (kwh)</th>
#       <th id="T_cf5cd_level0_col6" class="col_heading level0 col6" >decisao</th>
#       <th id="T_cf5cd_level0_col7" class="col_heading level0 col7" >condicao_falha</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf5cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf5cd_row0_col0" class="data row0 col0" >3429.216201</td>
#       <td id="T_cf5cd_row0_col1" class="data row0 col1" >62.081340</td>
#       <td id="T_cf5cd_row0_col2" class="data row0 col2" >1009.422578</td>
#       <td id="T_cf5cd_row0_col3" class="data row0 col3" >54.415615</td>
#       <td id="T_cf5cd_row0_col4" class="data row0 col4" >2128.903352</td>
#       <td id="T_cf5cd_row0_col5" class="data row0 col5" >1065.065160</td>
#       <td id="T_cf5cd_row0_col6" class="data row0 col6" >PRONTO PARA DECOLAR</td>
#       <td id="T_cf5cd_row0_col7" class="data row0 col7" ></td>
#     </tr>
#     <tr>
#       <th id="T_cf5cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf5cd_row1_col0" class="data row1 col0" >7849.211734</td>
#       <td id="T_cf5cd_row1_col1" class="data row1 col1" >86.501723</td>
#       <td id="T_cf5cd_row1_col2" class="data row1 col2" >653.320500</td>
#       <td id="T_cf5cd_row1_col3" class="data row1 col3" >128.174195</td>
#       <td id="T_cf5cd_row1_col4" class="data row1 col4" >6789.703356</td>
#       <td id="T_cf5cd_row1_col5" class="data row1 col5" >6008.208661</td>
#       <td id="T_cf5cd_row1_col6" class="data row1 col6" >PRONTO PARA DECOLAR</td>
#       <td id="T_cf5cd_row1_col7" class="data row1 col7" ></td>
#     </tr>
#     <tr>
#       <th id="T_cf5cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf5cd_row2_col0" class="data row2 col0" >7047.443444</td>
#       <td id="T_cf5cd_row2_col1" class="data row2 col1" >80.367017</td>
#       <td id="T_cf5cd_row2_col2" class="data row2 col2" >974.756036</td>
#       <td id="T_cf5cd_row2_col3" class="data row2 col3" >179.278329</td>
#       <td id="T_cf5cd_row2_col4" class="data row2 col4" >5663.820064</td>
#       <td id="T_cf5cd_row2_col5" class="data row2 col5" >4509.785699</td>
#       <td id="T_cf5cd_row2_col6" class="data row2 col6" >PRONTO PARA DECOLAR</td>
#       <td id="T_cf5cd_row2_col7" class="data row2 col7" ></td>
#     </tr>
#     <tr>
#       <th id="T_cf5cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf5cd_row3_col0" class="data row3 col0" >6431.206729</td>
#       <td id="T_cf5cd_row3_col1" class="data row3 col1" >85.832116</td>
#       <td id="T_cf5cd_row3_col2" class="data row3 col2" >1767.718305</td>
#       <td id="T_cf5cd_row3_col3" class="data row3 col3" >182.616302</td>
#       <td id="T_cf5cd_row3_col4" class="data row3 col4" >5520.040818</td>
#       <td id="T_cf5cd_row3_col5" class="data row3 col5" >3569.706211</td>
#       <td id="T_cf5cd_row3_col6" class="data row3 col6" >PRONTO PARA DECOLAR</td>
#       <td id="T_cf5cd_row3_col7" class="data row3 col7" ></td>
#     </tr>
#     <tr>
#       <th id="T_cf5cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cf5cd_row4_col0" class="data row4 col0" >5793.229182</td>
#       <td id="T_cf5cd_row4_col1" class="data row4 col1" >90.977739</td>
#       <td id="T_cf5cd_row4_col2" class="data row4 col2" >1896.549122</td>
#       <td id="T_cf5cd_row4_col3" class="data row4 col3" >204.369971</td>
#       <td id="T_cf5cd_row4_col4" class="data row4 col4" >5270.548914</td>
#       <td id="T_cf5cd_row4_col5" class="data row4 col5" >3169.629821</td>
#       <td id="T_cf5cd_row4_col6" class="data row4 col6" >PRONTO PARA DECOLAR</td>
#       <td id="T_cf5cd_row4_col7" class="data row4 col7" ></td>
#     </tr>
#   </tbody>
# </table>
